# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# %cd gdrive/MyDrive/
# %cd Machine\ learning
# %cd mask\ detection
# Out:
# git.ipynb  haarcascade_frontalface_default.xml	mask-detection.ipynb

# %%
# !git init
# Out:
# Initialized empty Git repository in /content/gdrive/My Drive/Machine learning/mask detection/.git/

# %%
# !git remote add origin https://Vasiljko:californiaherewecome123@github.com/Vasiljko/Malaria-detection.git
# !git remote -v
